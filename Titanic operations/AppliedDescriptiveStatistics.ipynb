# %%
import numpy as np
data = np.array([1, 3, 5, 2, 3, 7, 8, 4, 10, 0, 6, 7, 3, 0, 3, 0, 5, 7, 10, 1, 4, 9, 3])

# function by having the function return the average value of our dataset.
def compute_mean(dataset):
    """ Main function that calculates the average value across our data. """
    total = sum(dataset)
    length = len(dataset)
    return total/length

compute_mean(data)
# Out:
# 4.391304347826087

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('titanic.csv')

# %%
df[df['Survived'] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 15            16         1       2
# 17            18         1       2
# 19            20         1       3
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 39            40         1       3
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 52            53         1       1
# 53            54         1       2
# 55            56         1       1
# ...

# %%
ages = df[df['Sex'] == 'male']['Age'].dropna()

# %%
compute_mean(ages)
# Out:
# 30.72664459161148

# %%
IS_MALE = (df["Sex"] == "male")
IS_ALIVE = (df["Survived"] == 1)
ages = df[IS_MALE & IS_ALIVE]['Age'].dropna()

compute_mean(ages)
# Out:
# 27.276021505376345

# %%
df[(df['Survived'] == 1) & (df['Sex'] == 'male')]['Age'].mean()
# Out:
# 27.276021505376345

# %%
data = sorted(np.array([1, 3, 5, 2, 3, 7, 8, 4, 10, 0, 6, 7, 3, 0, 3, 0, 5, 7, 10, 1, 4, 9, 3]))

# TODO: Complete this function by having the function return the exact true median value of our dataset.
# HINT: Consider using DataFrame slicing to help with identifying the correct median value(s).
def compute_median(dataset):
    """ Main function that determines the median value across our data. """
    count = len(dataset)
    print(count)
    
    if count < 1:
        # TODO: Complete this if-statement
        return None
    if count % 2 == 1:
        # TODO: Complete this if-statement
        middle_index = (len(dataset) -1) // 2
        return dataset[middle_index]
    else:
        # TODO: Complete this if-else statement
        left_index = (len(dataset) - 1) // 2
        right_index = (len(dataset) -1)  // 2
        right_index + 1
        return data_set[left_idex] + data_set[right_index] / 2
    
compute_median(data)
# Out:
# 23
# 11
# 4

# %%
# NOTE: Tricker than it looks!
data = np.array([1, 3, 5, 2, 3, 7, 8, 4, 10, 0, 6, 7, 3, 0, 3, 0, 5, 7, 10, 1, 4, 9, 3])

# TODO: Complete this function by having the function return the relative mode across our dataset.
# HINT: Remember histograms and tokenization from CS 1.2? How may they help you here? 
def compute_mode(dataset):
    """ Main function that determines the mode value across our data. """
    data = {}
    for num in dataset:
        if num in data:
            data[num] += 1
        else:
            data[num] = 1
        
    return max(data, key=data.get)

compute_mode(data)
# Out:
# 3

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.DataFrame({'Rainy':[29,28,32,35,36,12,18,30,45,55, 32,32,32,32,32], 'City':['City_A']*5 + ['City_B']*5 + ['City_C']*5})
df
# Out:
#     Rainy    City
# 0      29  City_A
# 1      28  City_A
# 2      32  City_A
# 3      35  City_A
# 4      36  City_A
# 5      12  City_B
# 6      18  City_B
# 7      30  City_B
# 8      45  City_B
# 9      55  City_B
# 10     32  City_C
# 11     32  City_C
# 12     32  City_C
# 13     32  City_C
# 14     32  City_C

# %%
print(np.mean(df[df['City'] == 'City_A']['Rainy']))

print(np.mean(df[df['City'] == 'City_B']['Rainy']))

print(np.mean(df[df['City'] == 'City_C']['Rainy']))
# Out:
# 32.0
# 32.0
# 32.0

# %%
print(np.std(df[df['City'] == 'City_A']['Rainy']))

print(np.std(df[df['City'] == 'City_B']['Rainy']))

print(np.std(df[df['City'] == 'City_C']['Rainy']))
# Out:
# 3.1622776601683795
# 16.112107248898266
# 0.0

# %%
sns.lineplot(y='Rainy', x='City', data=df)
plt.show()

# %%
print([32 - np.std(df[df['City'] == 'City_A']['Rainy']), 32 + np.std(df[df['City'] == 'City_A']['Rainy'])])

print([32 - np.std(df[df['City'] == 'City_B']['Rainy']), 32 + np.std(df[df['City'] == 'City_B']['Rainy'])])

print([32 - np.std(df[df['City'] == 'City_C']['Rainy']), 32 + np.std(df[df['City'] == 'City_C']['Rainy'])])
# Out:
# [28.837722339831622, 35.16227766016838]
# [15.887892751101734, 48.11210724889827]
# [32.0, 32.0]

# %%
df = pd.read_csv('titanic.csv')

ls_fare = df['Fare'].dropna().values

np.percentile(ls_fare, 50)
# Out:
# 14.4542

# %%
df_fare = df[df['Fare'] <= 31]

# %%
len(df_fare) / len(df)
# Out:
# 0.7508417508417509

# %%
len(df_fare["Fare"].dropna())
# Out:
# 669

# %%
len(df["Fare"].dropna())
# Out:
# 891
